# %%
event_schema = [
    "event_id",
    "event_date",
    "event_type",   # research | model_release | adoption
    "ticker",
    "sector",
    "market_cap"
]

# %%
def compute_abnormal_returns(price_df, market_df, event_date, window=(-5, 5)):
    """
    price_df: DataFrame ['date', 'close']
    market_df: DataFrame ['date', 'market_close']
    """
    pass

# %%
EVENT_WINDOWS = {
    "research": [(-3, 3), (-5, 5)],
    "model_release": [(-5, 5), (-10, 10)],
    "adoption": [(-10, 10), (-30, 90)]
}

# %%
def plot_cumulative_returns(df):
    """
    df: columns ['days_from_event', 'car', 'event_type']
    """
    pass
